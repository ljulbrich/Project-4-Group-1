# %% [markdown]
# # Dataset exploration

# %%
from pathlib import Path
import pandas as pd
import sqlite3 as sql3
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from pathlib import Path

import warnings
warnings.filterwarnings('ignore')

# %%
app_record_pth = Path('Resources/application_record.csv')
cred_record_pth = Path('Resources/credit_record.csv')

app_record_df = pd.read_csv(filepath_or_buffer=app_record_pth, delimiter=',')
cred_record_df = pd.read_csv(filepath_or_buffer=cred_record_pth, delimiter=',')
display(app_record_df.head())
display(cred_record_df.head())
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
joined_df = app_record_df.join(cred_record_df, on='ID', how='inner')

# %%
app_record_df = app_record_df.get

# %%
engine = create_engine("sqlite:///../Resources/credit_score.sqlite", echo=false)
app_record_df.to_sql(name='application_record', if_exists='fail', )

# %%
for column in app_record_df:
    print(column)
    print(app_record_df[column].unique())
    print(app_record_df[column].value_counts())
    print(app_record_df[column].dtypes)
# Out:
# ID
# [5008804 5008805 5008806 ... 6841878 6842765 6842885]
# ID
# 7137299    2
# 7702238    2
# 7282535    2
# 7243768    2
# 7050948    2
#           ..
# 5690727    1
# 6621262    1
# 6621261    1
# 6621260    1
# 6842885    1
# Name: count, Length: 438510, dtype: int64
# int64
# CODE_GENDER
# ['M' 'F']
# CODE_GENDER
# F    294440
# M    144117
# Name: count, dtype: int64
# object
# FLAG_OWN_CAR
# ['Y' 'N']
# FLAG_OWN_CAR
# N    275459
# Y    163098
# Name: count, dtype: int64
# object
# FLAG_OWN_REALTY
# ['Y' 'N']
# FLAG_OWN_REALTY
# Y    304074
# N    134483
# Name: count, dtype: int64
# object
# CNT_CHILDREN
# [ 0  1  3  2  4  5 14 19  7  9 12  6]
# CNT_CHILDREN
# 0     304071
# 1      88527
# 2      39884
# 3       5430
# 4        486
# 5        133
# 7          9
# 9          5
# 12         4
# 6          4
# 14         3
# 19         1
# Name: count, dtype: int64
# int64
# AMT_INCOME_TOTAL
# [ 427500.    112500.    270000.    283500.    135000.    130500.
# ...

# %%
cred_record_df.index
# Out:
# RangeIndex(start=0, stop=1048575, step=1)

# %%
for row in cred_record_df.index:
    if cred_record_df['MONTHS_BALANCE'][row] != 0:
        cred_record_df.drop(index=row)
    else:
        continue

cred_record_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 for row in cred_record_df.index:
#       2     if cred_record_df['MONTHS_BALANCE'][row] != 0:
# ----> 3         cred_record_df.drop(index=row)
#       4     else:
#       5         continue
#
# File c:\Users\Jasper\anaconda3\envs\monash\lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
# ...
